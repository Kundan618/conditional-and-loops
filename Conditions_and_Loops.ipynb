# %% [markdown]
# ###**Q1. What are conditional statements? Explain conditional statements with syntax and examples.**
#
# ####**conditional statements:**
#  * Programming Languages are tools that allow us to write code that instructs the computer to do something. In
# every programming language, the code needs to make decisions and carry out actions accordingly
# depending on different inputs.
#  * Human Beings make decisions all the time. For example, every morning, we make a decision between eating or
# not eating before starting our daily chores. Conditional statements allow us to represent such decision-making
# in JavaScript, from the choice that must be made.
#  * JavaScript is a programming language that is commonly used to create interactive and dynamic elements on
# websites. One of the key features of JavaScript is the ability to use conditional statements to control the flow of
# a program.
#  * Conditions work on boolean values, true or false. It is true if it meets the requirement, false otherwise. That is
# expressions (conditions) are evaluated to be either true or false.
#
# ####**Conditional statements in JavaScript:**
#
# **1. If statement:**
#    * THE most basic form of a conditional statement in the if statment
#    * The syntax for an if statement ia as follws:
#
#    ```
#    java script
#    if (condition ){
#     //statements
#    }
#    ```
#    * The condition is any expression that can be evaluated as true or false. For example, you can use a comparison
#    operator (such as <, >, ==) to compare two values, or you can use a logical operator (such as &&, ||) to
#    combine multiple conditions.
#
#   **Example**
# ```
# let number = 20; // this is a number variable
# if(number % 2 === 0 ) { //
#     console.log(`is an even number`); // prints if the number is even
# }
# ```
#
#   **Output:**
#
#  ![{F44E05E0-FAF2-42ED-9F37-B3D64E139AF0}.png](data:image/png;base64,...)
#
#
# **2. if-else statements:**
#    * An if-else statements can aolso include an optional else statement, which will execute if the condition is false.
#
#    * The syntax for if-else statment is a follows;
#    ```
#    let number = 33; // this is a number variable
#     if(number % 20 === 0 ) { //
#       console.log(`is an even number`); // prints if the number is even
#       }else {
#         console.log(`is an odd number`);//  prints if the number is odd
#       }
#
#    ```
#
#   **Output**
#
#   ![{BA6A56E4-72CD-4DF3-878B-5E1255D02B62}.png](data:image/png;base64,...)
#
# **3. Nested if statement:**
#
#    * We can nest if else statements inside another if else statements.
#    * The syntax for an nested if statement is as follows:
#
#    ```
#     if(condition1){
#       if(condition2){
#       //statements
#       }
#     }
#
#    ```
#
#   **Example**
#
#    ```
#     let temperature = 25;
#     let isRaining = false ;
#
#     if (temperature > 20) {
#       console.log("It's a warm day.");
#         if (isRaining) {
#            console.log("But it's raining, so bring an umbrella!");
#           } else {
#              console.log("And it's not raining, enjoy the sun!");
#           }
#      } else {
#       console.log("It's a cooler day.");
#       }
#
#    ```
#
#   **Output**
#
#    ![{E34634BA-DA27-4F35-B370-4C3717A1C5A1}.png](data:image/png;base64,...)
#
#
#
# **4. if else if ladder:**
#
#    * JavaScript also supports the use of else if statement, which allows you to chain multiple conditions together also called if else ladder.
#
#    * The syntax for an if else if ladder is as follows:
#
#   ```
#
#     if (condition1){
#       //statement1
#       } else if(condition2){
#         //statemnt2
#       }
#       else{
#         //statement3
#       }
#
#     ```
#
#      **Example:**
#
#     ```
#       //example of if else if ladder statemtement
#       let score = 85; // Example score
#
#       if (score >= 90) {
#       console.log("Grade: A");
#       } else if (score >= 80) {
#       console.log("Grade: B");
#       } else if (score >= 70) {
#       console.log("Grade: C");
#       } else if (score >= 60) {
#       console.log("Grade: D");
#       } else {
#        console.log("Grade: F");
#       }
#
#     ```
#
#      **Output:**
#
#      ![{4C1E5FF9-CA7F-42CA-9862-43129C4976D8}.png](data:image/png;base64,...)

# %% [markdown]
# ###**Q2. Write a program that grades students based on their marks.**
# * If greater than 90 then A Grad
# * If between 70 and 90 then a B grad
# * If between 50 and 70 then a C grad
# * Below 50 then an F grade
#
#   ```
# let score =  39;
# if(score>=90 && score<=100){
#     console.log("Grade : A");
# } else if(score>=70 && score<=89){
#     console.log("Grade : B");
# } else if(score>=60 && score<=69){
#     console.log("Grade : C");
# } else if(score>=50 && score<=59){
#     console.log("Grade : D");
# } else {
# console.log("Grade : F");
# }
# ```
#
#   **Output:**
#   ![{71B0FCF1-7173-4FE3-AF44-933ACA2AB1F8}.png](data:image/png;base64,...)

# %% [markdown]
# ###**Q3. What are loops, and what do we need them? Explain different types of loops with their syntax and examples.**
#
#  * Loops are used to reduce repetitive tasks by repeatedly executing a block of code as long as a specified condition is true. This makes code more concise and efficient.
#
#  * Suppose we want to print 'Hello World' five times. Instead of manually writing the print statement repeatedly, we can use a loop to automate the task and execute it based on the given condition.
#
#  ```
#  for (let i = 0; i < 5; i++) {
#     console.log("Hello World!");
# }
# ```
# **Output:**
#
#  ````
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
#  ````
#
#
#  * The different types of loops available in JavaScript.
#
#  * **For loop :**
#      The for loop repeats a block of code a specific number of times. It contains initialization, condition, and increment/decrement in one line.
#     * **syntax:**
#     ```
#     for (initialization; condition; increment/decrement) {
#     // Code to execute
#     }
#     ```
#
#    * **Exmaple:**
#
#       ```
#     //Generate number between two numbers
#     for(let num = 5;num<=15;num++){
#       console.log(num);
#     }
#
#       ```
#
#    * **Output:**
#
#     ![{CC2EF343-121A-4F4D-95E1-F7D87587D36D}.png](data:image/png;base64,...)
#
#
#
#   * **While loop:**
#       The while loop executes as long as the condition is true. It can be thought of as a repeating if statement.
#        * **Syntax:**
#      ```
#       while (condition) {
#       // Code to execute
#     }
#     ```
#
#    * **Example:**
#
#       ```
#     // Prints from 1 to 25 in ascending order
#     let i = 1;
#     while (i <= 25) {
#       console.log(i);
#       i++;
#     }
#
#      ```
#
#     * **Output:**
#
#       ![{4A5070D1-AD21-493A-BE3F-25E23BA1F760}.png](data:image/png;base64,...)
#
#
#
# * **do-while Loop:**
#     The do-while loop is similar to while loop except it executes the code block at least once before checking the condition.
#     * **Syntax:**
#      ```
#     do {
#     // Code to execute
#     } while (condition);
#       ```
#
#     * **Example:**
#       ```
#       // Prints from 1 to 25 in descending order
#       let j = 25;
#       while (j >= 1) {
#         console.log(j);
#         j--;
#       }
#      ```
#
#    * **Output:**
#
#        ![{B07384F3-2AD2-4A15-B2B9-2355E63C2BC4}.png](data:image/png;base64,...)

# %% [markdown]
# ###**Q4. Generate numbers between any 2 given numbers.**
#
#    ```
#     //Generate number between two numbers
#     for(let num = 5;num<=15;num++){
#       console.log(num);
#     }
#
#   ```
# **Output:**
#
#    ![{CC2EF343-121A-4F4D-95E1-F7D87587D36D}.png](data:image/png;base64,...)

# %% [markdown]
# ###**Q5. Use the while loop to print numbers from 1 to 25 in ascending and descending order.**
#
#   ```
#   // Prints from 1 to 25 in ascending and descending order
#   let i = 1;
#   while (i <= 25) {
#     console.log(i);
#     i++;
#   }
#   let j = 25;
#   while (j >= 1) {
#     console.log(j);
#     j--;
#   }
#   ```
#    **Output for ascending order:**
#
#    ![{4A5070D1-AD21-493A-BE3F-25E23BA1F760}.png](data:image/png;base64,...)
#
#   **Output for Descending order:**
#
#    ![{B07384F3-2AD2-4A15-B2B9-2355E63C2BC4}.png](data:image/png;base64,...)
